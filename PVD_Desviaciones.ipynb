# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Leer los datos de Excel
# Asegúrate de reemplazar 'ruta_a_tu_archivo.xlsx' con la ruta real de tu archivo Excel
df = pd.read_excel('Muestreos.xlsx')

# Supongamos que los tamaños de las nanopartículas están en una columna llamada 'Tamaño'
tamanos = df['Length']

# Calcular la desviación estándar
desviacion_estandar = np.std(tamanos)

# Imprimir la desviación estándar
print(f'Desviación estándar: {desviacion_estandar}')

# Crear el histograma
#plt.hist(tamanos, bins='auto', edgecolor='black')

# Añadir título y etiquetas
#plt.title('Histograma de tamaños de nanopartículas')
#plt.xlabel('Tamaño de nanopartículas')
#plt.ylabel('Frecuencia')

plt.errorbar(range(len(tamanos)), tamanos, yerr=desviacion_estandar, fmt='o', ecolor='red', capsize=5)

# Añadir título y etiquetas
plt.title('Muestreo de Nanopartículas')
plt.xlabel('Índice de Muestra')
plt.ylabel('Tamaño de Nanopartículas')

# Mostrar la gráfica
plt.show()
# Out:
# Desviación estándar: 2.0617823955826897

# %%
# Leer los datos de Excel
# Asegúrate de reemplazar 'ruta_a_tu_archivo.xlsx' con la ruta real de tu archivo Excel
df3 = pd.read_csv('M3_60Muestreos.csv')

# Supongamos que los tamaños de las nanopartículas están en una columna llamada 'Tamaño'
tamanos3 = df3['Length']

# Calcular la desviación estándar
desviacion_estandar3 = np.std(tamanos3)

# Imprimir la desviación estándar
print(f'Desviación estándar: {desviacion_estandar3}')

# Crear el histograma
#plt.hist(tamanos3, bins='auto', edgecolor='black')

# Añadir título y etiquetas
#plt.title('Histograma de tamaños de nanopartículas')
#plt.xlabel('Tamaño de nanopartículas')
#plt.ylabel('Frecuencia')

plt.errorbar(range(len(tamanos3)), tamanos3, yerr=desviacion_estandar3, fmt='o', ecolor='red', capsize=5)

# Añadir título y etiquetas
plt.title('Muestreo de Nanopartículas')
plt.xlabel('Índice de Muestra')
plt.ylabel('Tamaño de Nanopartículas')

# Mostrar el histograma
plt.show()
# Out:
# Desviación estándar: 16.103239112226944

# %%
# Leer los datos de Excel
# Asegúrate de reemplazar 'ruta_a_tu_archivo.xlsx' con la ruta real de tu archivo Excel
df2 = pd.read_csv('M2_80Muestreos.csv')

# Supongamos que los tamaños de las nanopartículas están en una columna llamada 'Tamaño'
tamanos2 = df2['Length']

# Calcular la desviación estándar
desviacion_estandar2 = np.std(tamanos2)

# Imprimir la desviación estándar
print(f'Desviación estándar: {desviacion_estandar2}')

# Crear el histograma
#plt.hist(tamanos2, bins='auto', edgecolor='black')

# Añadir título y etiquetas
#plt.title('Histograma de tamaños de nanopartículas')
#plt.xlabel('Tamaño de nanopartículas')
#plt.ylabel('Frecuencia')

plt.errorbar(range(len(tamanos2)), tamanos2, yerr=desviacion_estandar2, fmt='o', ecolor='red', capsize=5)

# Añadir título y etiquetas
plt.title('Muestreo de Nanopartículas')
plt.xlabel('Índice de Muestra')
plt.ylabel('Tamaño de Nanopartículas')

# Mostrar el histograma
plt.show()
# Out:
# Desviación estándar: 2.891472367988971

# %%
# Leer los datos de Excel
# Asegúrate de reemplazar 'ruta_a_tu_archivo.xlsx' con la ruta real de tu archivo Excel
df1 = pd.read_csv('M1_70Muestreos.csv')

# Supongamos que los tamaños de las nanopartículas están en una columna llamada 'Tamaño'
tamanos1 = df1['Length']

# Calcular la desviación estándar
desviacion_estandar1 = np.std(tamanos1)

# Imprimir la desviación estándar
print(f'Desviación estándar: {desviacion_estandar1}')

# Crear el histograma
#plt.hist(tamanos1, bins='auto', edgecolor='black')

# Añadir título y etiquetas
#plt.title('Histograma de tamaños de nanopartículas')
#plt.xlabel('Tamaño de nanopartículas')
#plt.ylabel('Frecuencia')

plt.errorbar(range(len(tamanos1)), tamanos1, yerr=desviacion_estandar1, fmt='o', ecolor='red', capsize=5)

# Añadir título y etiquetas
plt.title('Muestreo de Nanopartículas')
plt.xlabel('Índice de Muestra')
plt.ylabel('Tamaño de Nanopartículas')

# Mostrar el histograma
plt.show()
# Out:
# Desviación estándar: 8.962895502756535
